# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904719-cell/tong-chan-le/blob/main/bai_tap_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Nhập số lượng phần tử: "))
arr = list(map(int, input("Nhập dãy số: ").split()))

tong_chan = 0
tong_le = 0

for x in arr:
    if x % 2 == 0:
       tong_chan += x
    else:
       tong_le += x

print("Tổng số chẵn =", tong_chan)
print("Tổng số lẻ =", tong_le)
